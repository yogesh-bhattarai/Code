# %%
from sklearn.datasets import make_regression

# %%
import numpy as np

# %%
X,y= make_regression(n_samples=4, n_features=1, n_informative=1,n_targets=1,noise= 80,random_state=13)

# %%
X
# Out:
# array([[-0.71239066],
#        [ 0.45181234],
#        [-0.04450308],
#        [ 0.75376638]])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model= LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y)
plt.plot(X, model.predict(X), color= 'black')

# %%
model.coef_
# Out:
# array([78.35063668])

# %%
model.intercept_
# Out:
# 26.15963284313262

# %%
# lets up apply the value of slope is m=78.35
#let assume the value of the intercept is b=0

# %%
y_pred= ((78.35*X)+0).reshape(4)

# %%
y_pred
# Out:
# array([-55.81580837,  35.39949674,  -3.48681619,  59.05759577])

# %%
plt.scatter(X,y)
plt.plot(X,model.predict(X), color='red',label= 'OLS')
plt.plot(X,y_pred, color='#00FF00', label= 'b=0')
plt.legend()
plt.show()

# %%
m= 78.35
b=0
loss_slope= -2*np.sum(y-m*X.ravel()-b)

# %%
loss_slope
# Out:
# -209.27763408209216

# %%
X
# Out:
# array([[-0.71239066],
#        [ 0.45181234],
#        [-0.04450308],
#        [ 0.75376638]])

# %%
lr=0.1
step_size= lr*loss_slope

# %%
step_size
# Out:
# -20.927763408209216

# %%
b=b-step_size

# %%
b
# Out:
# 20.927763408209216

# %%
y_pred1= ((78.35*X)+b).reshape(4)

# %%
y_pred1
# Out:
# array([-34.88804496,  56.32726015,  17.44094722,  79.98535918])

# %%
plt.scatter(X,y)
plt.plot(X, model.predict(X),color='red')
plt.plot(X, y_pred1, color='blue')
plt.plot(X, y_pred, color= 'black')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
loss_slope= -2*np.sum(y-m*X.ravel()-b)

# %%
loss_slope
# Out:
# -41.85552681641843

# %%
step_size= loss_slope*lr

# %%
b=b-step_size

# %%
b
# Out:
# 25.11331608985106

# %%
b=-100
m=78.35
lr= 0.1
epochs=10

for i in range(epochs):
    loss_slope= -2(np.sum(y-m*X.ravel()-b)
    y_pred = m*X+b
    plt.plot(X,y_pred)
plt.scatter(X,y)
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp\ipykernel_16960\2805472626.py", line 8
#     y_pred = m*X+b
#     ^
# SyntaxError: invalid syntax

# %%
y_pred = m*X+b

# %%
y_pred
# Out:
# array([[-30.70249228],
#        [ 60.51281283],
#        [ 21.6264999 ],
#        [ 84.17091186]])
